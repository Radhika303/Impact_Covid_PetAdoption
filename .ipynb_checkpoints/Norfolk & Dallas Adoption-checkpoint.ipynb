# %%
#import dependencies
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing and Cleaning Norfolk Adoption Data
#     * Check link for csv file: https://data.norfolk.gov/Government/Norfolk-Animal-Care-and-Adoption-Center-NACC-/vfm4-5wv6

# %%
#read in csv file
adoption= "Norfolk_Animal.csv"
adoption= pd.read_csv(adoption)
adoption.shape
#adoption.head()
#adoption.dtypes
# Out:
# (29276, 21)

# %%
#Converting Intake Date and Outcome Date to pandas date format
adoption['Intake Date'] = pd.to_datetime(adoption['Intake Date'],format='%m/%d/%Y')
adoption['Outcome Date'] = pd.to_datetime(adoption['Outcome Date'],format='%m/%d/%Y')

#adoption.shape
#adoption.dtypes
adoption.head()
# Out:
#       Animal ID Animal Name Animal Type            Sex  Years Old  Months Old  \
# 0       A000455    SNOWBALL         Dog  Neutered Male        4.0        0.00
# 1       A000455    SNOWBALL         Dog  Neutered Male        4.0        0.00
# 2       A000601    SHEILA E         Cat  Spayed Female        0.0        1.80
# 3       A001474     CHARLES         Dog  Neutered Male        1.0        0.00
# 4       A001474     CHARLES         Dog  Neutered Male        1.0        0.00
# ...         ...         ...         ...            ...        ...         ...
# 29271   A059219        OZZY         Dog           Male        NaN         NaN
# 29272   A059228         NaN         Cat  Neutered Male        8.0         NaN
# 29273   A059254         NaN         Cat         Female        NaN        1.85
# 29274   A059260   CHOCOLATE         Dog           Male        2.0         NaN
# 29275   A059267         NaN       Other        Unknown        3.0         NaN
#
#        Primary Breed Primary Color       Tag Number Intake Date  ...  \
# 0         POODLE MIN         WHITE       L17-011989  2017-08-16  ...
# 1         POODLE MIN         WHITE       L17-011502  2017-05-03  ...
# 2        DOMESTIC SH        CALICO       L16-010051  2016-08-20  ...
# 3      LABRADOR RETR        YELLOW              NaN  2017-04-27  ...
# 4      LABRADOR RETR        YELLOW       L16-009301  2016-03-30  ...
# ...              ...           ...              ...         ...  ...
# 29271        MASTIFF           RED  981020039165640  2020-11-22  ...
# 29272    DOMESTIC SH     ORG TABBY              NaN  2020-11-23  ...
# 29273    DOMESTIC SH     ORG TABBY              NaN  2020-11-27  ...
# 29274     POODLE TOY         BROWN  985112001208056  2020-11-29  ...
# 29275        RACCOON      TRICOLOR              NaN  2020-11-29  ...
#
#          Intake Subtype              Outcome Type          Outcome Subtype  \
# 0      Over the Counter                  Adoption                  Walk-In
# 1      Over the Counter                  Adoption                  Walk-In
# 2              Transfer                  Adoption      Website Information
# 3      Over the Counter           Return to Owner                  Walk-In
# 4        Animal Cruelty           Return to Owner                      NaN
# ...                 ...                       ...                      ...
# 29271  Over the Counter                  Adoption                  Walk-In
# 29272    Animal Cruelty  Disposal of Deceased Pet                      NaN
# 29273    Animal Control                    Foster  Underage or Underweight
# 29274    Animal Control           Return to Owner                  Walk-In
# 29275    Animal Control                Euthanized                 Wildlife
#
#       Outcome Date Intake Month  Intake Day of the Week  Intake Year  \
# 0       2017-08-19          NaN                     NaN          NaN
# 1       2017-05-13          NaN                     NaN          NaN
# 2       2016-10-02          NaN                     NaN          NaN
# 3       2017-06-06          NaN                     NaN          NaN
# 4       2016-04-15          NaN                     NaN          NaN
# ...            ...          ...                     ...          ...
# 29271   2020-11-25          NaN                     NaN          NaN
# 29272   2020-11-23          NaN                     NaN          NaN
# 29273   2020-11-30          NaN                     NaN          NaN
# 29274   2020-11-29          NaN                     NaN          NaN
# 29275   2020-11-29          NaN                     NaN          NaN
#
#        Outcome Month  Outcome Day of the Week  Outcome Year
# 0                NaN                      NaN           NaN
# 1                NaN                      NaN           NaN
# 2                NaN                      NaN           NaN
# 3                NaN                      NaN           NaN
# 4                NaN                      NaN           NaN
# ...              ...                      ...           ...
# 29271            NaN                      NaN           NaN
# 29272            NaN                      NaN           NaN
# 29273            NaN                      NaN           NaN
# 29274            NaN                      NaN           NaN
# 29275            NaN                      NaN           NaN
#
# [29276 rows x 21 columns]

# %%
#Pulling only the columns with outcome type as adoption
adoption= adoption.loc[adoption['Outcome Type'] == 'Adoption']
adoption.head()
#adoption.dtypes
# Out:
#       Animal ID Animal Name Animal Type            Sex  Years Old  Months Old  \
# 0       A000455    SNOWBALL         Dog  Neutered Male        4.0         0.0
# 1       A000455    SNOWBALL         Dog  Neutered Male        4.0         0.0
# 2       A000601    SHEILA E         Cat  Spayed Female        0.0         1.8
# 17      A002987        ENZO         Dog  Neutered Male        1.0         0.0
# 28      A006357      SKIPPY         Dog  Neutered Male        5.0         0.0
# ...         ...         ...         ...            ...        ...         ...
# 29257   A059140       SARAH         Cat  Neutered Male        1.0         4.0
# 29258   A059142         NaN         Dog           Male        NaN         6.0
# 29265   A059175         NaN         Dog  Spayed Female        1.0         NaN
# 29270   A059217       DODGE         Dog           Male        NaN         1.9
# 29271   A059219        OZZY         Dog           Male        NaN         NaN
#
#        Primary Breed Primary Color       Tag Number Intake Date  ...  \
# 0         POODLE MIN         WHITE       L17-011989  2017-08-16  ...
# 1         POODLE MIN         WHITE       L17-011502  2017-05-03  ...
# 2        DOMESTIC SH        CALICO       L16-010051  2016-08-20  ...
# 17          PIT BULL         BLACK       L17-011517  2017-04-30  ...
# 28            BEAGLE      TRICOLOR  982000123128327  2016-05-03  ...
# ...              ...           ...              ...         ...  ...
# 29257    DOMESTIC SH     BRN TABBY  982126056569270  2020-11-14  ...
# 29258  GERM SHEPHERD           TAN  981020039171781  2020-11-14  ...
# 29265       PIT BULL    BR BRINDLE  981020039180182  2020-11-19  ...
# 29270       PIT BULL           TAN  981020039180052  2020-11-21  ...
# 29271        MASTIFF           RED  981020039165640  2020-11-22  ...
#
#          Intake Subtype Outcome Type      Outcome Subtype Outcome Date  \
# 0      Over the Counter     Adoption              Walk-In   2017-08-19
# 1      Over the Counter     Adoption              Walk-In   2017-05-13
# 2              Transfer     Adoption  Website Information   2016-10-02
# 17     Over the Counter     Adoption              Walk-In   2017-05-16
# 28     Over the Counter     Adoption                  NaN   2016-05-18
# ...                 ...          ...                  ...          ...
# 29257          Transfer     Adoption              Walk-In   2020-11-16
# 29258    Animal Control     Adoption                  NaN   2020-11-28
# 29265    Animal Control     Adoption              Walk-In   2020-11-25
# 29270    Animal Control     Adoption  Website Information   2020-11-27
# 29271  Over the Counter     Adoption              Walk-In   2020-11-25
#
#       Intake Month  Intake Day of the Week  Intake Year  Outcome Month  \
# 0              NaN                     NaN          NaN            NaN
# 1              NaN                     NaN          NaN            NaN
# 2              NaN                     NaN          NaN            NaN
# 17             NaN                     NaN          NaN            NaN
# 28             NaN                     NaN          NaN            NaN
# ...            ...                     ...          ...            ...
# 29257          NaN                     NaN          NaN            NaN
# 29258          NaN                     NaN          NaN            NaN
# 29265          NaN                     NaN          NaN            NaN
# 29270          NaN                     NaN          NaN            NaN
# 29271          NaN                     NaN          NaN            NaN
#
#        Outcome Day of the Week  Outcome Year
# 0                          NaN           NaN
# 1                          NaN           NaN
# 2                          NaN           NaN
# 17                         NaN           NaN
# 28                         NaN           NaN
# ...                        ...           ...
# 29257                      NaN           NaN
# 29258                      NaN           NaN
# 29265                      NaN           NaN
# 29270                      NaN           NaN
# 29271                      NaN           NaN
#
# [10842 rows x 21 columns]

# %%
#Adding outcome month and outcome year as additional columns
adoption['Outcome Month'] = adoption['Outcome Date'].map(lambda x: x.strftime('%m'))
adoption['Outcome Year'] = adoption['Outcome Date'].map(lambda x: x.strftime('%Y'))
adoption.head()
# Out:
#       Animal ID Animal Name Animal Type            Sex  Years Old  Months Old  \
# 0       A000455    SNOWBALL         Dog  Neutered Male        4.0         0.0
# 1       A000455    SNOWBALL         Dog  Neutered Male        4.0         0.0
# 2       A000601    SHEILA E         Cat  Spayed Female        0.0         1.8
# 17      A002987        ENZO         Dog  Neutered Male        1.0         0.0
# 28      A006357      SKIPPY         Dog  Neutered Male        5.0         0.0
# ...         ...         ...         ...            ...        ...         ...
# 29257   A059140       SARAH         Cat  Neutered Male        1.0         4.0
# 29258   A059142         NaN         Dog           Male        NaN         6.0
# 29265   A059175         NaN         Dog  Spayed Female        1.0         NaN
# 29270   A059217       DODGE         Dog           Male        NaN         1.9
# 29271   A059219        OZZY         Dog           Male        NaN         NaN
#
#        Primary Breed Primary Color       Tag Number Intake Date  ...  \
# 0         POODLE MIN         WHITE       L17-011989  2017-08-16  ...
# 1         POODLE MIN         WHITE       L17-011502  2017-05-03  ...
# 2        DOMESTIC SH        CALICO       L16-010051  2016-08-20  ...
# 17          PIT BULL         BLACK       L17-011517  2017-04-30  ...
# 28            BEAGLE      TRICOLOR  982000123128327  2016-05-03  ...
# ...              ...           ...              ...         ...  ...
# 29257    DOMESTIC SH     BRN TABBY  982126056569270  2020-11-14  ...
# 29258  GERM SHEPHERD           TAN  981020039171781  2020-11-14  ...
# 29265       PIT BULL    BR BRINDLE  981020039180182  2020-11-19  ...
# 29270       PIT BULL           TAN  981020039180052  2020-11-21  ...
# 29271        MASTIFF           RED  981020039165640  2020-11-22  ...
#
#          Intake Subtype Outcome Type      Outcome Subtype Outcome Date  \
# 0      Over the Counter     Adoption              Walk-In   2017-08-19
# 1      Over the Counter     Adoption              Walk-In   2017-05-13
# 2              Transfer     Adoption  Website Information   2016-10-02
# 17     Over the Counter     Adoption              Walk-In   2017-05-16
# 28     Over the Counter     Adoption                  NaN   2016-05-18
# ...                 ...          ...                  ...          ...
# 29257          Transfer     Adoption              Walk-In   2020-11-16
# 29258    Animal Control     Adoption                  NaN   2020-11-28
# 29265    Animal Control     Adoption              Walk-In   2020-11-25
# 29270    Animal Control     Adoption  Website Information   2020-11-27
# 29271  Over the Counter     Adoption              Walk-In   2020-11-25
#
#       Intake Month  Intake Day of the Week  Intake Year  Outcome Month  \
# 0              NaN                     NaN          NaN             08
# 1              NaN                     NaN          NaN             05
# 2              NaN                     NaN          NaN             10
# 17             NaN                     NaN          NaN             05
# 28             NaN                     NaN          NaN             05
# ...            ...                     ...          ...            ...
# 29257          NaN                     NaN          NaN             11
# 29258          NaN                     NaN          NaN             11
# 29265          NaN                     NaN          NaN             11
# 29270          NaN                     NaN          NaN             11
# 29271          NaN                     NaN          NaN             11
#
#       Outcome Day of the Week  Outcome Year
# 0                         NaN          2017
# 1                         NaN          2017
# 2                         NaN          2016
# 17                        NaN          2017
# 28                        NaN          2016
# ...                       ...           ...
# 29257                     NaN          2020
# 29258                     NaN          2020
# 29265                     NaN          2020
# 29270                     NaN          2020
# 29271                     NaN          2020
#
# [10842 rows x 21 columns]

# %%
#Pulling out only the columns relevant for our research
norfolk_df= adoption[["Animal ID","Animal Type","Sex", "Years Old","Months Old","Primary Breed", "Primary Color","Intake Type","Intake Date","Outcome Type","Outcome Date","Outcome Month","Outcome Year"]]
norfolk_df.head()
# Out:
#       Animal ID Animal Type            Sex  Years Old  Months Old  \
# 0       A000455         Dog  Neutered Male        4.0         0.0
# 1       A000455         Dog  Neutered Male        4.0         0.0
# 2       A000601         Cat  Spayed Female        0.0         1.8
# 17      A002987         Dog  Neutered Male        1.0         0.0
# 28      A006357         Dog  Neutered Male        5.0         0.0
# ...         ...         ...            ...        ...         ...
# 29257   A059140         Cat  Neutered Male        1.0         4.0
# 29258   A059142         Dog           Male        NaN         6.0
# 29265   A059175         Dog  Spayed Female        1.0         NaN
# 29270   A059217         Dog           Male        NaN         1.9
# 29271   A059219         Dog           Male        NaN         NaN
#
#        Primary Breed Primary Color        Intake Type Intake Date  \
# 0         POODLE MIN         WHITE             Return  2017-08-16
# 1         POODLE MIN         WHITE  Owner Surrendered  2017-05-03
# 2        DOMESTIC SH        CALICO           Transfer  2016-08-20
# 17          PIT BULL         BLACK              Stray  2017-04-30
# 28            BEAGLE      TRICOLOR  Owner Surrendered  2016-05-03
# ...              ...           ...                ...         ...
# 29257    DOMESTIC SH     BRN TABBY           Transfer  2020-11-14
# 29258  GERM SHEPHERD           TAN              Stray  2020-11-14
# 29265       PIT BULL    BR BRINDLE              Stray  2020-11-19
# 29270       PIT BULL           TAN              Stray  2020-11-21
# 29271        MASTIFF           RED  Owner Surrendered  2020-11-22
#
#       Outcome Type Outcome Date Outcome Month Outcome Year
# 0         Adoption   2017-08-19            08         2017
# 1         Adoption   2017-05-13            05         2017
# 2         Adoption   2016-10-02            10         2016
# 17        Adoption   2017-05-16            05         2017
# 28        Adoption   2016-05-18            05         2016
# ...            ...          ...           ...          ...
# 29257     Adoption   2020-11-16            11         2020
# 29258     Adoption   2020-11-28            11         2020
# 29265     Adoption   2020-11-25            11         2020
# 29270     Adoption   2020-11-27            11         2020
# 29271     Adoption   2020-11-25            11         2020
#
# [10842 rows x 13 columns]

# %% [markdown]
# # Importing and Cleaning COVID Data for Norfolk,VA

# %%
# URL for GET requests to retrieve COVID data for Norfolk, VA
url = "https://data.virginia.gov/resource/bre9-aqqr.json?locality=Norfolk"
response = requests.get(url)

# Print status code
print(response.status_code)
# Out:
# 200

# %%
# Retrieving data and converting it into JSON
requests.get(url).json()
data = response.json()
#print(json.dumps(data, indent=4))

# %%
#converting from json to a dataframe
COVID_df = pd.DataFrame(data)
COVID_df.head()
# Out:
#                  report_date   fips locality vdh_health_district total_cases  \
# 0    2020-12-09T00:00:00.000  51710  Norfolk             Norfolk        7106
# 1    2020-12-08T00:00:00.000  51710  Norfolk             Norfolk        7038
# 2    2020-12-07T00:00:00.000  51710  Norfolk             Norfolk        6894
# 3    2020-12-06T00:00:00.000  51710  Norfolk             Norfolk        6783
# 4    2020-12-05T00:00:00.000  51710  Norfolk             Norfolk        6786
# ..                       ...    ...      ...                 ...         ...
# 263  2020-11-23T00:00:00.000  51710  Norfolk             Norfolk        6297
# 264  2020-11-24T00:00:00.000  51710  Norfolk             Norfolk        6344
# 265  2020-11-25T00:00:00.000  51710  Norfolk             Norfolk        6378
# 266  2020-11-26T00:00:00.000  51710  Norfolk             Norfolk        6401
# 267  2020-11-27T00:00:00.000  51710  Norfolk             Norfolk        6408
#
#     hospitalizations deaths
# 0                490     98
# 1                483     98
# 2                475     93
# 3                476     93
# 4                476     93
# ..               ...    ...
# 263              439     88
# 264              442     89
# 265              456     89
# 266              457     89
# 267              457     89
#
# [268 rows x 7 columns]

# %% [markdown]
# # Analyzing Norfolk Adoption Data:

# %%
norfolk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10842 entries, 0 to 29271
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Animal ID      10842 non-null  object
#  1   Animal Type    10842 non-null  object
#  2   Sex            10842 non-null  object
#  3   Years Old      6640 non-null   float64
#  4   Months Old     6799 non-null   float64
#  5   Primary Breed  10842 non-null  object
#  6   Primary Color  10842 non-null  object
#  7   Intake Type    10842 non-null  object
#  8   Intake Date    10842 non-null  datetime64[ns]
#  9   Outcome Type   10842 non-null  object
#  10  Outcome Date   10842 non-null  datetime64[ns]
#  11  Outcome Month  10842 non-null  object
#  12  Outcome Year   10842 non-null  object
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 1.2+ MB

# %%
#grouping by year to see if the data is complete 
group= norfolk_df.groupby(['Outcome Year'])
year= group.count()
year
# Out:
#               Animal ID  Animal Type   Sex  Years Old  Months Old  \
# Outcome Year
# 2015                223          223   223        223         223
# 2016               2391         2391  2391       2391        2390
# 2017               2240         2240  2240       1214        1208
# 2018               2195         2195  2195       1045        1088
# 2019               2239         2239  2239       1010        1160
# 2020               1554         1554  1554        757         730
#
#               Primary Breed  Primary Color  Intake Type  Intake Date  \
# Outcome Year
# 2015                    223            223          223          223
# 2016                   2391           2391         2391         2391
# 2017                   2240           2240         2240         2240
# 2018                   2195           2195         2195         2195
# 2019                   2239           2239         2239         2239
# 2020                   1554           1554         1554         1554
#
#               Outcome Type  Outcome Date  Outcome Month
# Outcome Year
# 2015                   223           223            223
# 2016                  2391          2391           2391
# 2017                  2240          2240           2240
# 2018                  2195          2195           2195
# 2019                  2239          2239           2239
# 2020                  1554          1554           1554

# %%
#Pulling data for year 2018
year1_df = norfolk_df.loc[norfolk_df['Outcome Year'] == '2018']
year1_adoptions = year1_df["Outcome Month"].value_counts()
year1_adoptions
# Out:
# 08    259
# 12    231
# 06    211
# 07    195
# 05    186
# 10    185
# 11    181
# 03    172
# 09    161
# 04    156
# 02    139
# 01    119
# Name: Outcome Month, dtype: int64

# %%
#Pulling data for year 2019
year2_df = norfolk_df.loc[norfolk_df['Outcome Year'] == '2019']
year2_adoptions = year2_df["Outcome Month"].value_counts()
year2_adoptions
# Out:
# 08    252
# 10    250
# 07    249
# 06    190
# 09    189
# 05    185
# 11    181
# 12    174
# 01    157
# 04    140
# 03    136
# 02    136
# Name: Outcome Month, dtype: int64

# %%
#Pulling data for year 2020
year3_df = norfolk_df.loc[norfolk_df['Outcome Year'] == '2020']
year3_adoptions = year3_df["Outcome Month"].value_counts()
year3_adoptions
# Out:
# 11    186
# 07    173
# 01    167
# 03    164
# 10    154
# 02    154
# 08    154
# 09    148
# 06    110
# 04     80
# 05     64
# Name: Outcome Month, dtype: int64

# %%
#saving years 2018 through 2020 as a df
adoption_by_month = pd.DataFrame({
    "2018": year1_adoptions,
    "2019": year2_adoptions,
    "2020": year3_adoptions
})
adoption_by_month= adoption_by_month.fillna(0)
adoption_by_month
# Out:
#     2018  2019   2020
# 01   119   157  167.0
# 02   139   136  154.0
# 03   172   136  164.0
# 04   156   140   80.0
# 05   186   185   64.0
# 06   211   190  110.0
# 07   195   249  173.0
# 08   259   252  154.0
# 09   161   189  148.0
# 10   185   250  154.0
# 11   181   181  186.0
# 12   231   174    0.0

# %%
#plotting a line graph that shows adoption rates in years 2018 to 2020
fig = plt.figure()
ax=fig.add_subplot(111)

ax.plot()
ax.plot(adoption_by_month.index,adoption_by_month["2018"],color = 'orange',label = '2018')
ax.plot(adoption_by_month.index,adoption_by_month["2019"],color="maroon", label='2019' )
ax.plot(adoption_by_month.index,adoption_by_month["2020"],color="teal", label='2020')
#plt.plot(adoption_by_month['Year'],adoption_by_month['Number of Adoptions'],color="r", marker="o", markersize=7, linestyle="dashed", linewidth=1)

plt.xlabel('Month')
plt.ylabel('# of pets adopted')
plt.title("Norfolk Pet Adoption Rates by Year")
#plt.legend(handles=('2018', '2019','2020'), loc="best")

plt.legend(loc="best",fontsize="small",fancybox=True)
plt.grid(True)

#saving the figure
plt.savefig("Norfolk Adoption Rates by Year.png")

# %% [markdown]
# We notice that adoption rates are lower in 2020 compared to previous years.

# %% [markdown]
# # Analyzing COVID Data

# %%
#COVID_df.dtypes
COVID_df['Outcome Dates'] = pd.to_datetime(COVID_df['report_date'],format='%Y/%m/%d')
COVID_df['Outcome Month'] = COVID_df['Outcome Dates'].map(lambda x: x.strftime('%m'))
COVID_df
# Out:
#                  report_date   fips locality vdh_health_district total_cases  \
# 0    2020-12-09T00:00:00.000  51710  Norfolk             Norfolk        7106
# 1    2020-12-08T00:00:00.000  51710  Norfolk             Norfolk        7038
# 2    2020-12-07T00:00:00.000  51710  Norfolk             Norfolk        6894
# 3    2020-12-06T00:00:00.000  51710  Norfolk             Norfolk        6783
# 4    2020-12-05T00:00:00.000  51710  Norfolk             Norfolk        6786
# ..                       ...    ...      ...                 ...         ...
# 263  2020-11-23T00:00:00.000  51710  Norfolk             Norfolk        6297
# 264  2020-11-24T00:00:00.000  51710  Norfolk             Norfolk        6344
# 265  2020-11-25T00:00:00.000  51710  Norfolk             Norfolk        6378
# 266  2020-11-26T00:00:00.000  51710  Norfolk             Norfolk        6401
# 267  2020-11-27T00:00:00.000  51710  Norfolk             Norfolk        6408
#
#     hospitalizations deaths Outcome Dates Outcome Month
# 0                490     98    2020-12-09            12
# 1                483     98    2020-12-08            12
# 2                475     93    2020-12-07            12
# 3                476     93    2020-12-06            12
# 4                476     93    2020-12-05            12
# ..               ...    ...           ...           ...
# 263              439     88    2020-11-23            11
# 264              442     89    2020-11-24            11
# 265              456     89    2020-11-25            11
# 266              457     89    2020-11-26            11
# 267              457     89    2020-11-27            11
#
# [268 rows x 9 columns]

# %% [markdown]
# Pulling the total number of cases for each month

# %%
covid_group = COVID_df.groupby(['Outcome Month'])
covid_max_df=covid_group['total_cases'].max()
covid_max_df


COVID_by_month = pd.DataFrame({
    "# of Cases": covid_max_df
   
})
COVID_by_month
# Out:
#               # of Cases
# Outcome Month
# 03                     8
# 04                    99
# 05                   503
# 06                   915
# 07                   987
# 08                  4394
# 09                  4881
# 10                  5493
# 11                  6528
# 12                  7106

# %% [markdown]
# Plotting the cuminlative COVID cases

# %%
plt.plot(COVID_by_month.index,COVID_by_month['# of Cases'],color = 'm',label = 'Cases')

plt.xlabel('Month')
plt.ylabel('# of COVID cases')
plt.title("Norfolk, VA Cumulative COVID cases")

plt.legend(loc="best",fontsize="small",fancybox=True)
plt.grid(True)

plt.savefig("Norfolk, VA Cumulative COVID cases")

# %% [markdown]
# Plotting the delta number of cases month over month

# %%
COVID_by_month['# of Cases'] = COVID_by_month['# of Cases'].astype(int)

COVID_diff = COVID_by_month['# of Cases'].diff().fillna(0)

COVID_diff

COVID_per_month = pd.DataFrame({"# of Cases": COVID_diff,
                              "Month": COVID_diff.index})
COVID_per_month
# Out:
#                # of Cases Month
# Outcome Month
# 03                    0.0    03
# 04                   91.0    04
# 05                  404.0    05
# 06                  412.0    06
# 07                   72.0    07
# 08                 3407.0    08
# 09                  487.0    09
# 10                  612.0    10
# 11                 1035.0    11
# 12                  578.0    12

# %%
plt.plot(COVID_per_month.index,COVID_per_month['# of Cases'],color = 'darkred',label = 'Cases')


plt.xlabel('Month')
plt.ylabel('# of new COVID cases')
plt.title("Norfolk, VA new COVID cases per month")

plt.legend(loc="best",fontsize="small",fancybox=True)
plt.grid(True)

plt.savefig("Norfolk, VA new COVID cases per month")

# %%
#Plot adoption data and COVID cases side-by-side
#fig = plt.figure()

#ax = plt.subplot(111)
#ax.bar(adoption_by_month.index,adoption_by_month['2020'], width=0.5, color='b', align='center', label = 'adoptions')
#ax.bar(COVID_per_month.index,COVID_per_month['# of Cases'], width=0.5, color='g', align='center',label='COVID cases')
#ax.autoscale(tight=True)
#plt.xlabel('Month')
#plt.ylabel('# of pets adopted')
#plt.title("Adoption vs COVID cases Comparison")
#plt.legend(handles=('2018', '2019','2020'), loc="best")
#fig.tight_layout()
#plt.legend(loc="best",fontsize="small",fancybox=True)
#plt.grid(True)
#plt.show()

# %% [markdown]
# Plotting a scatter plot of Norfolk COVID cases vs Norfolk pet adoption

# %%
new_row = pd.DataFrame({"# of Cases": 0,"Month": "02"},index =[0])

# simply concatenate both dataframes 
COVID_per_month = pd.concat([new_row, COVID_per_month]).reset_index(drop = True) 
new_row = pd.DataFrame({"# of Cases": 0,"Month": "01"},index =[0])

# simply concatenate both dataframes 
COVID_per_month = pd.concat([new_row, COVID_per_month]).reset_index(drop = True) 

COVID_per_month
# Out:
#     # of Cases Month
# 0          0.0    01
# 1          0.0    02
# 2          0.0    03
# 3         91.0    04
# 4        404.0    05
# 5        412.0    06
# 6         72.0    07
# 7       3407.0    08
# 8        487.0    09
# 9        612.0    10
# 10      1035.0    11
# 11       578.0    12

# %%
plt.scatter(adoption_by_month['2020'],COVID_per_month['# of Cases'],marker='o', c= 'b')


plt.xlabel("Adoptions")
plt.ylabel("COVID cases")

plt.title("Norfolk COVID cases vs pet adoption")

plt.savefig("Norfolk COVID cases vs pet adoption.png")

# %% [markdown]
# Analysis:
# * Checking the assumptions related to t-test

# %%
population1= adoption_by_month['2020'].mean()
population2= COVID_per_month['# of Cases'].mean()

population1_std= np.std(adoption_by_month['2020'])
population2_std= np.std(COVID_per_month['# of Cases'])

population1_std, population2_std
# Out:
# (53.005502858979966, 902.4332385279257)

# %%
plt.hist(adoption_by_month['2020'])
print(st.normaltest(adoption_by_month['2020']))
# Out:
# NormaltestResult(statistic=6.020364134826666, pvalue=0.04928270516893548)

# %%
plt.hist(COVID_per_month['# of Cases'])
print(st.normaltest(COVID_per_month['# of Cases']))
# Out:
# NormaltestResult(statistic=25.367620197303985, pvalue=3.1009250162270873e-06)

# %%
st.ttest_ind(adoption_by_month['2020'],COVID_per_month['# of Cases'],equal_var= False)
# Out:
# Ttest_indResult(statistic=-1.6950221554424156, pvalue=0.11796733678932625)

# %% [markdown]
# With the pvalue of 11.7%, we fail to reject the null hypothesis (there is no correlation between COVID positive cases and pet adoption rates).
#
# The mean and the standard deviations for population 1 (adoption rates in 2020) and population 2(COVID cases) are significantly different from each other.
#
# Both datasets are not normally distributed,and the standard deviations are not roughly equal, therefore the assumption related to a t-test are not valid for these datasets.

# %% [markdown]
# # Importing and Cleaning Dallas Adoption Data

# %%
adoption= "Dallas_adoption.csv"
Dallas_adoption= pd.read_csv(adoption)
Dallas_adoption.head()
#Dallas_adoption.shape
#Dallas_adoption.dtypes
# Out:
#       Animal Id Animal Type     Animal Breed Kennel Number  \
# 0      A0144701         DOG         HAVANESE         VT 12
# 1      A0442587         DOG      TERRIER MIX       FREEZER
# 2      A0458972         DOG        CATAHOULA     RECEIVING
# 3      A0525642         DOG    GERM SHEPHERD      INJD 001
# 4      A0565586         DOG    SILKY TERRIER       LFD 119
# ...         ...         ...              ...           ...
# 31913  A1108003         DOG         PIT BULL         QD 09
# 31914  A1107788         DOG     CHIHUAHUA SH       LFD 085
# 31915  A1088331         DOG         PIT BULL         DC 05
# 31916  A1106166         DOG    LABRADOR RETR        AD 060
# 31917  A1108155         DOG  WELSH CORGI CAR        PCD 20
#
#                   Kennel Status  Tag Type Activity Number  Activity Sequence  \
# 0                     IMPOUNDED       NaN             NaN                  1
# 1                     IMPOUNDED       NaN             NaN                  1
# 2                   UNAVAILABLE       NaN      A19-195601                  1
# 3                     IMPOUNDED       NaN      A19-196573                  1
# 4                   UNAVAILABLE       NaN             NaN                  1
# ...                         ...       ...             ...                ...
# 31913  RELEASED FROM QUARANTINE       NaN      A20-237793                  1
# 31914               UNAVAILABLE       NaN      A20-237295                  1
# 31915               UNAVAILABLE       NaN      A20-236813                  1
# 31916                   PRE-LAB       NaN             NaN                  1
# 31917               UNAVAILABLE       NaN      A20-238151                  1
#
#       Source Id Census Tract  ... Outcome Time Receipt Number Impound Number  \
# 0      P0098773       006301  ...     11:31:00     R19-558731     K19-486742
# 1      P0492284       007102  ...     00:00:00            NaN     K19-486954
# 2      P9991718       004600  ...     13:36:00            NaN     K19-482022
# 3      P0903792       016605  ...     17:35:00            NaN     K19-483073
# 4      P0890077       006900  ...     12:57:00     R19-558750     K19-486694
# ...         ...          ...  ...          ...            ...            ...
# 31913  P0938311       031704  ...     10:50:00     R20-571061     K20-513587
# 31914  P0937967       000500  ...     10:16:00     R20-571060     K20-513344
# 31915  P0907761       000601  ...     18:16:00     R20-571057     K20-513080
# 31916  P0544963          NaN  ...     00:00:00            NaN     K20-513098
# 31917  P0024514       003700  ...     00:00:00            NaN     K20-513808
#
#        Service Request Number                       Outcome Condition  \
# 0                         NaN                                APP SICK
# 1                         NaN                                    DEAD
# 2                         NaN  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 3                         NaN  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 4                         NaN                                 APP WNL
# ...                       ...                                     ...
# 31913                     NaN                                 APP WNL
# 31914                     NaN                                 APP WNL
# 31915                     NaN                                 APP WNL
# 31916                     NaN                                     NaN
# 31917                     NaN                                     NaN
#
#         Chip Status     Animal Origin Additional Information     Month    Year
# 0         SCAN CHIP  OVER THE COUNTER      RETURNED TO OWNER  NOV.2019  FY2020
# 1         SCAN CHIP  OVER THE COUNTER                    NaN  NOV.2019  FY2020
# 2      SCAN NO CHIP             SWEEP                    NaN  OCT.2019  FY2020
# 3         SCAN CHIP             SWEEP                 TAGGED  OCT.2019  FY2020
# 4         SCAN CHIP  OVER THE COUNTER      RETURNED TO OWNER  NOV.2019  FY2020
# ...             ...               ...                    ...       ...     ...
# 31913     SCAN CHIP             FIELD                    NaN  SEP.2020  FY2020
# 31914  SCAN NO CHIP             FIELD                    NaN  SEP.2020  FY2020
# 31915  SCAN NO CHIP             FIELD                    NaN  SEP.2020  FY2020
# 31916     SCAN CHIP  OVER THE COUNTER                    NaN  SEP.2020  FY2020
# 31917     SCAN CHIP             FIELD                    NaN  SEP.2020  FY2020
#
# [31918 rows x 34 columns]

# %%
#Pulling out only the columns relevant for our research
Dallas_df= Dallas_adoption[['Animal Type',"Animal Breed","Outcome Type","Outcome Date"]]
Dallas_df.head()
# Out:
#       Animal Type     Animal Breed       Outcome Type Outcome Date
# 0             DOG         HAVANESE  RETURNED TO OWNER   11/09/2019
# 1             DOG      TERRIER MIX    DEAD ON ARRIVAL   11/10/2019
# 2             DOG        CATAHOULA  RETURNED TO OWNER   10/03/2019
# 3             DOG    GERM SHEPHERD           TRANSFER   10/15/2019
# 4             DOG    SILKY TERRIER  RETURNED TO OWNER   11/09/2019
# ...           ...              ...                ...          ...
# 31913         DOG         PIT BULL  RETURNED TO OWNER   10/07/2020
# 31914         DOG     CHIHUAHUA SH  RETURNED TO OWNER   10/07/2020
# 31915         DOG         PIT BULL  RETURNED TO OWNER   10/07/2020
# 31916         DOG    LABRADOR RETR              OTHER          NaN
# 31917         DOG  WELSH CORGI CAR              OTHER          NaN
#
# [31918 rows x 4 columns]

# %%
Dallas_df['Outcome Date'] = pd.to_datetime(Dallas_df['Outcome Date'],format='%m/%d/%Y')
Dallas_df.head()
# Out:
#       Animal Type     Animal Breed       Outcome Type Outcome Date
# 0             DOG         HAVANESE  RETURNED TO OWNER   2019-11-09
# 1             DOG      TERRIER MIX    DEAD ON ARRIVAL   2019-11-10
# 2             DOG        CATAHOULA  RETURNED TO OWNER   2019-10-03
# 3             DOG    GERM SHEPHERD           TRANSFER   2019-10-15
# 4             DOG    SILKY TERRIER  RETURNED TO OWNER   2019-11-09
# ...           ...              ...                ...          ...
# 31913         DOG         PIT BULL  RETURNED TO OWNER   2020-10-07
# 31914         DOG     CHIHUAHUA SH  RETURNED TO OWNER   2020-10-07
# 31915         DOG         PIT BULL  RETURNED TO OWNER   2020-10-07
# 31916         DOG    LABRADOR RETR              OTHER          NaT
# 31917         DOG  WELSH CORGI CAR              OTHER          NaT
#
# [31918 rows x 4 columns]

# %%
Dallas_df = Dallas_df.loc[Dallas_df['Outcome Type'] == 'ADOPTION']
Dallas_df.head()
# Out:
#       Animal Type     Animal Breed Outcome Type Outcome Date Outcome Month  \
# 16            DOG     CHIHUAHUA SH     ADOPTION   2019-10-30            10
# 19            DOG    GERM SHEPHERD     ADOPTION   2019-11-20            11
# 23            DOG       LHASA APSO     ADOPTION   2019-11-03            11
# 25            DOG            BOXER     ADOPTION   2019-10-16            10
# 26            DOG            BOXER     ADOPTION   2019-11-16            11
# ...           ...              ...          ...          ...           ...
# 31874         DOG         PIT BULL     ADOPTION   2020-10-05            10
# 31875         DOG    BORDER COLLIE     ADOPTION   2020-10-06            10
# 31890         DOG  BLACK MOUTH CUR     ADOPTION   2020-10-06            10
# 31904         DOG         PIT BULL     ADOPTION   2020-10-07            10
# 31905         DOG         PIT BULL     ADOPTION   2020-10-07            10
#
#       Outcome Year
# 16            2019
# 19            2019
# 23            2019
# 25            2019
# 26            2019
# ...            ...
# 31874         2020
# 31875         2020
# 31890         2020
# 31904         2020
# 31905         2020
#
# [10087 rows x 6 columns]

# %%
Dallas_df= Dallas_df.dropna()
Dallas_df['Outcome Month'] = Dallas_df['Outcome Date'].map(lambda x: x.strftime('%m'))
Dallas_df['Outcome Year'] = Dallas_df['Outcome Date'].map(lambda x: x.strftime('%Y'))
Dallas_df.head()
# Out:
#       Animal Type     Animal Breed Outcome Type Outcome Date Outcome Month  \
# 16            DOG     CHIHUAHUA SH     ADOPTION   2019-10-30            10
# 19            DOG    GERM SHEPHERD     ADOPTION   2019-11-20            11
# 23            DOG       LHASA APSO     ADOPTION   2019-11-03            11
# 25            DOG            BOXER     ADOPTION   2019-10-16            10
# 26            DOG            BOXER     ADOPTION   2019-11-16            11
# ...           ...              ...          ...          ...           ...
# 31874         DOG         PIT BULL     ADOPTION   2020-10-05            10
# 31875         DOG    BORDER COLLIE     ADOPTION   2020-10-06            10
# 31890         DOG  BLACK MOUTH CUR     ADOPTION   2020-10-06            10
# 31904         DOG         PIT BULL     ADOPTION   2020-10-07            10
# 31905         DOG         PIT BULL     ADOPTION   2020-10-07            10
#
#       Outcome Year
# 16            2019
# 19            2019
# 23            2019
# 25            2019
# 26            2019
# ...            ...
# 31874         2020
# 31875         2020
# 31890         2020
# 31904         2020
# 31905         2020
#
# [10087 rows x 6 columns]

# %%
#Pulling data for year 2018. There is no data for the year 2018
Dallas_2018 = Dallas_df.loc[Dallas_df['Outcome Year'] == '2018']
Dallas_2018_adoptions = Dallas_2018["Outcome Month"].value_counts()
Dallas_2018_adoptions
# Out:
# Series([], Name: Outcome Month, dtype: int64)

# %%
#Pulling data for year 2019
Dallas_2019 = Dallas_df.loc[Dallas_df['Outcome Year'] == '2019']
Dallas_2019_adoptions = Dallas_2019["Outcome Month"].value_counts()
Dallas_2019_adoptions
# Out:
# 12    1419
# 11    1359
# 10     941
# Name: Outcome Month, dtype: int64

# %%
#Pulling data for year 2020
Dallas_2020 = Dallas_df.loc[Dallas_df['Outcome Year'] == '2020']
Dallas_2020_adoptions = Dallas_2020["Outcome Month"].value_counts()
Dallas_2020_adoptions
# Out:
# 01    1314
# 02    1140
# 03     922
# 08     606
# 06     550
# 07     546
# 09     530
# 05     405
# 04     292
# 10      63
# Name: Outcome Month, dtype: int64

# %%
#Saving adoption data for 2019 and 2020 into a df 
Dallas_by_month = pd.DataFrame({
    "2019": Dallas_2019_adoptions,
    "2020": Dallas_2020_adoptions
})

Dallas_by_month= Dallas_by_month.fillna(0)
Dallas_by_month
# Out:
#       2019    2020
# 01     0.0  1314.0
# 02     0.0  1140.0
# 03     0.0   922.0
# 04     0.0   292.0
# 05     0.0   405.0
# 06     0.0   550.0
# 07     0.0   546.0
# 08     0.0   606.0
# 09     0.0   530.0
# 10   941.0    63.0
# 11  1359.0     0.0
# 12  1419.0     0.0

# %%
#plotting a line graph that shows adoption rates in years 2019 and 2020
fig = plt.figure()
ax=fig.add_subplot(111)

ax.plot()
ax.plot(Dallas_by_month.index,Dallas_by_month["2019"],color="b", label='2019' )
ax.plot(Dallas_by_month.index,Dallas_by_month["2020"],color="g", label='2020')

plt.xlabel('Month')
plt.ylabel('# of pets adopted')
plt.title("Dallas Adoption Rates by Year")

plt.legend(loc="best",fontsize="small",fancybox=True)
plt.grid(True)

plt.savefig("Dallas Adoption Rates by Year.png")

# %% [markdown]
# # Importing and Cleaning Dallas COVID Data

# %%
COVID= "us_counties.csv"
Dallas_COVID= pd.read_csv(COVID)
Dallas_COVID.head()
#adoption.shape
#Dallas_adoption.dtypes
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1       2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2       2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3       2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4       2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...            ...         ...         ...      ...    ...     ...
# 800432  2020-12-05  Sweetwater     Wyoming  56037.0   2098    10.0
# 800433  2020-12-05       Teton     Wyoming  56039.0   1739     2.0
# 800434  2020-12-05       Uinta     Wyoming  56041.0   1187     5.0
# 800435  2020-12-05    Washakie     Wyoming  56043.0    519     8.0
# 800436  2020-12-05      Weston     Wyoming  56045.0    419     2.0
#
# [800437 rows x 6 columns]

# %%
Dallas_COVID= Dallas_COVID.loc[Dallas_COVID['state']== 'Texas']
Dallas_COVID.head()
# Out:
#               date  county  state     fips  cases  deaths
# 143     2020-02-12   Bexar  Texas  48029.0      1     0.0
# 154     2020-02-13   Bexar  Texas  48029.0      2     0.0
# 165     2020-02-14   Bexar  Texas  48029.0      2     0.0
# 176     2020-02-15   Bexar  Texas  48029.0      2     0.0
# 187     2020-02-16   Bexar  Texas  48029.0      2     0.0
# ...            ...     ...    ...      ...    ...     ...
# 800061  2020-12-05    Wood  Texas  48499.0    953    54.0
# 800062  2020-12-05  Yoakum  Texas  48501.0    627    11.0
# 800063  2020-12-05   Young  Texas  48503.0   1002    23.0
# 800064  2020-12-05  Zapata  Texas  48505.0    571     9.0
# 800065  2020-12-05  Zavala  Texas  48507.0    816    24.0
#
# [60398 rows x 6 columns]

# %%
Dallas_COVID= Dallas_COVID.loc[Dallas_COVID['county']== 'Dallas']
Dallas_COVID.head()
# Out:
#               date  county  state     fips   cases  deaths
# 1133    2020-03-10  Dallas  Texas  48113.0       2     0.0
# 1329    2020-03-11  Dallas  Texas  48113.0       3     0.0
# 1576    2020-03-12  Dallas  Texas  48113.0       8     0.0
# 1881    2020-03-13  Dallas  Texas  48113.0       9     0.0
# 2247    2020-03-14  Dallas  Texas  48113.0      11     0.0
# ...            ...     ...    ...      ...     ...     ...
# 786885  2020-12-01  Dallas  Texas  48113.0  139977  1549.0
# 790131  2020-12-02  Dallas  Texas  48113.0  141617  1565.0
# 793377  2020-12-03  Dallas  Texas  48113.0  143739  1585.0
# 796622  2020-12-04  Dallas  Texas  48113.0  144645  1604.0
# 799868  2020-12-05  Dallas  Texas  48113.0  146320  1620.0
#
# [271 rows x 6 columns]

# %%
Dallas_COVID['date'] = pd.to_datetime(Dallas_COVID['date'],format='%Y/%m/%d')
Dallas_COVID['Month'] = Dallas_COVID['date'].map(lambda x: x.strftime('%m'))
Dallas_COVID['Year'] = Dallas_COVID['date'].map(lambda x: x.strftime('%Y'))
Dallas_COVID.head()
# Out:
#              date  county  state     fips   cases  deaths Month  Year
# 1133   2020-03-10  Dallas  Texas  48113.0       2     0.0    03  2020
# 1329   2020-03-11  Dallas  Texas  48113.0       3     0.0    03  2020
# 1576   2020-03-12  Dallas  Texas  48113.0       8     0.0    03  2020
# 1881   2020-03-13  Dallas  Texas  48113.0       9     0.0    03  2020
# 2247   2020-03-14  Dallas  Texas  48113.0      11     0.0    03  2020
# ...           ...     ...    ...      ...     ...     ...   ...   ...
# 786885 2020-12-01  Dallas  Texas  48113.0  139977  1549.0    12  2020
# 790131 2020-12-02  Dallas  Texas  48113.0  141617  1565.0    12  2020
# 793377 2020-12-03  Dallas  Texas  48113.0  143739  1585.0    12  2020
# 796622 2020-12-04  Dallas  Texas  48113.0  144645  1604.0    12  2020
# 799868 2020-12-05  Dallas  Texas  48113.0  146320  1620.0    12  2020
#
# [271 rows x 8 columns]

# %%
dallas_group = Dallas_COVID.groupby(['Month'])
dallas_max=dallas_group['cases'].max()
dallas_max


Dallas_by_month = pd.DataFrame({
    "cases": dallas_max
   
})
Dallas_by_month
# Out:
#         cases
# Month
# 03        631
# 04       3531
# 05      10234
# 06      21338
# 07      51299
# 08      74576
# 09      86500
# 10     102642
# 11     138798
# 12     146320

# %%
Dallas_by_month['cases'] = Dallas_by_month['cases'].astype(int)

Dallas_diff = Dallas_by_month['cases'].diff().fillna(0)

Dallas_diff

Dallas_per_month = pd.DataFrame({"cases": Dallas_diff,
                              "Month": Dallas_diff.index})
Dallas_per_month
# Out:
#          cases Month
# Month
# 03         0.0    03
# 04      2900.0    04
# 05      6703.0    05
# 06     11104.0    06
# 07     29961.0    07
# 08     23277.0    08
# 09     11924.0    09
# 10     16142.0    10
# 11     36156.0    11
# 12      7522.0    12

# %% [markdown]
# Plotting the delta number of cases month over month

# %%
plt.plot(Dallas_per_month.index,Dallas_per_month['cases'],color = 'c',label = 'Cases')


plt.xlabel('Month')
plt.ylabel('# of new COVID cases')
plt.title("Dallas, TX new COVID cases per month")

plt.legend(loc="best",fontsize="small",fancybox=True)
plt.grid(True)

plt.savefig("Dallas, TX new COVID cases per month.png")

# %%
new_row = pd.DataFrame({"cases": 0,"Month": "02"},index =[0])

# simply concatenate both dataframes 
Dallas_per_month = pd.concat([new_row, Dallas_per_month]).reset_index(drop = True) 
new_row = pd.DataFrame({"cases": 0,"Month": "01"},index =[0])

# simply concatenate both dataframes 
Dallas_per_month = pd.concat([new_row, Dallas_per_month]).reset_index(drop = True) 

Dallas_per_month
# Out:
#       cases Month
# 0       0.0    01
# 1       0.0    02
# 2       0.0    03
# 3    2900.0    04
# 4    6703.0    05
# 5   11104.0    06
# 6   29961.0    07
# 7   23277.0    08
# 8   11924.0    09
# 9   16142.0    10
# 10  36156.0    11
# 11   7522.0    12

# %% [markdown]
# Plotting a scatter plot of Dallas COVID cases vs Dallas pet adoption

# %%
plt.scatter(Dallas_by_month['2020'],Dallas_per_month['cases'], c="crimson")


plt.xlabel("Adoptions")
plt.ylabel("COVID cases")
plt.title("Dallas COVID cases vs pet adoption")


plt.savefig("Dallas COVID cases vs pet adoption.png")

# %%
Dallas_pop= np.std(Dallas_by_month['2020'])
Dallas_pop2= np.std(Dallas_per_month['cases'])

Dallas_pop, Dallas_pop2
# Out:
# (408.14669203880874, 11597.155930981527)

# %%
st.ttest_ind(Dallas_by_month['2020'],Dallas_per_month['cases'],equal_var= False)
# Out:
# Ttest_indResult(statistic=-3.3182674870712097, pvalue=0.006830329816449098)

# %% [markdown]
# With the pvalue of 0.68%, we reject the null hypothesis (there is a correlation between COVID positive cases and pet adoption rates in Dallas).

# %% [markdown]
# Plotting a scatter plot of COVID cases and pet adoptions for both Norfolk and Dallas

# %%
fig, ax = plt.subplots()
ax.margins(0.05)

ax.plot(adoption_by_month['2020'],COVID_per_month['# of Cases'], marker='o', linestyle='', ms=12, mfc="c", label='Norfolk')
ax.plot(Dallas_by_month['2020'],Dallas_per_month['cases'], marker='+', linestyle='', ms=12, mfc="m", label='Dallas')
ax.legend()

plt.xlabel("Adoptions")
plt.ylabel("COVID cases")
plt.title("COVID Cases vs Pet Adoption")

plt.savefig("COVID Cases vs Pet Adoption.png")
